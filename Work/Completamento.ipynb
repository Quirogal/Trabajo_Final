# %% [markdown]
# Popularidad de Canciones y Artistas:
# 1. ¿Cuáles son las canciones más populares según diferentes métricas (reproducciones, likes, etc.)?
# 2. ¿Qué artistas tienen mayor presencia en los datos y cómo ha cambiado esto con el tiempo?
# Tendencias Temporales:
# 1. ¿Qué tendencias temporales se pueden identificar en la popularidad de las canciones y artistas?
# 2. ¿Existen patrones estacionales o eventos específicos que afecten la popularidad?
# Segmentación de Usuarios:
# 1. ¿Cómo se pueden segmentar los usuarios basándonos en su comportamiento de escucha?
# 2. ¿Existen grupos distintos de usuarios con preferencias musicales similares?
# Recomendaciones y Personalización:
# 1. ¿Qué características influyen más en las recomendaciones de canciones?
# 2. ¿Cómo se puede mejorar la personalización de recomendaciones basándose en los datos disponibles?
# 4
# Proceso de Refinamiento
# A medida que avancemos con el análisis de los datos, es probable que surjan nuevas preguntas y algunas de las actuales se modifiquen. Este proceso iterativo es fundamental para profundizar en el entendimiento de los datos y mejorar la calidad del análisis.

# %% [markdown]
# ### Import pandas as pd
# Para poder visualizar los codigos de python

# %%
import pandas as pd

# %% [markdown]
# ### df=pd.read_csv('../Datasets/.csv')
# Muy importante para cargar nuestro data sets devemos hubicarlo principalmente una carpetta llamada igual,
# de esta manera vamos a cargar el .csv

# %%
df=pd.read_csv('../Datasets/spotify_dataset.csv')

# %%
df
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 0         1                          1                        8
# 1         2                          2                        3
# 2         3                          1                       11
# 3         4                          3                        5
# 4         5                          5                        1
# ...     ...                        ...                      ...
# 1551   1552                        195                        1
# 1552   1553                        196                        1
# 1553   1554                        197                        1
# 1554   1555                        198                        1
# 1555   1556                        199                        1
#
#      Week of Highest Charting                           Song Name     Streams  \
# 0      2021-07-23--2021-07-30                             Beggin'  48,633,449
# 1      2021-07-23--2021-07-30           STAY (with Justin Bieber)  47,248,719
# 2      2021-06-25--2021-07-02                            good 4 u  40,162,559
# 3      2021-07-02--2021-07-09                          Bad Habits  37,799,456
# 4      2021-07-23--2021-07-30   INDUSTRY BABY (feat. Jack Harlow)  33,948,454
# ...                       ...                                 ...         ...
# 1551   2019-12-27--2020-01-03                           New Rules   4,630,675
# 1552   2019-12-27--2020-01-03                  Cheirosa - Ao Vivo   4,623,030
# 1553   2019-12-27--2020-01-03           Havana (feat. Young Thug)   4,620,876
# 1554   2019-12-27--2020-01-03          Surtada - Remix Brega Funk   4,607,385
# 1555   2019-12-27--2020-01-03  Lover (Remix) [feat. Shawn Mendes]   4,595,450
#
#                              Artist Artist Followers                 Song ID  \
# 0                          Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# 1                     The Kid LAROI          2230022  5HCyWlXZPP0y6Gqq8TgA20
# 2                    Olivia Rodrigo          6266514  4ZtFanR9U6ndgddUvNcjcG
# 3                        Ed Sheeran         83293380  6PQ88X9TkUIAUIZJHW2upE
# 4                         Lil Nas X          5473565  27NovPIUIRrOZoCHxABJwK
# ...                             ...              ...                     ...
# 1551                       Dua Lipa         27167675  2ekn2ttSfGqwhhate0LSR0
# 1552                 Jorge & Mateus         15019109  2PWjKmjyTZeDpmOUa3a5da
# 1553                 Camila Cabello         22698747  1rfofaqEpACxVEHIZBJe6W
# 1554  Dadá Boladão, Tati Zaqui, OIK           208630  5F8ffc8KWKNawllr5WsW0r
# 1555                   Taylor Swift         42227614  3i9UVldZOE0aD0JnyfAZZ0
#
#                                                   Genre  ... Danceability  \
# 0                ['indie rock italiano', 'italian pop']  ...        0.714
# 1                                ['australian hip hop']  ...        0.591
# 2                                               ['pop']  ...        0.563
# 3                                     ['pop', 'uk pop']  ...        0.808
# 4                         ['lgbtq+ hip hop', 'pop rap']  ...        0.736
# ...                                                 ...  ...          ...
# 1551                     ['dance pop', 'pop', 'uk pop']  ...        0.762
# 1552           ['sertanejo', 'sertanejo universitario']  ...        0.528
# 1553  ['dance pop', 'electropop', 'pop', 'post-teen ...  ...        0.765
# 1554                     ['brega funk', 'funk carioca']  ...        0.832
# 1555                           ['pop', 'post-teen pop']  ...        0.448
#
#      Energy Loudness Speechiness Acousticness Liveness    Tempo Duration (ms)  \
# 0       0.8   -4.808      0.0504        0.127    0.359  134.002        211560
# 1     0.764   -5.484      0.0483       0.0383    0.103  169.928        141806
# 2     0.664   -5.044       0.154        0.335   0.0849  166.928        178147
# 3     0.897   -3.712      0.0348       0.0469    0.364  126.026        231041
# 4     0.704   -7.409      0.0615       0.0203   0.0501  149.995        212000
# ...     ...      ...         ...          ...      ...      ...           ...
# 1551    0.7   -6.021      0.0694      0.00261    0.153  116.073        209320
# 1552   0.87   -3.123      0.0851         0.24    0.333   152.37        181930
# 1553  0.523   -4.333        0.03        0.184    0.132  104.988        217307
# 1554   0.55   -7.026      0.0587        0.249    0.182  154.064        152784
# 1555  0.603   -7.176       0.064        0.433   0.0862  205.272        221307
#
#      Valence  Chord
# 0      0.589      B
# 1      0.478  C#/Db
# 2      0.688      A
# 3      0.591      B
# 4      0.894  D#/Eb
# ...      ...    ...
# 1551   0.608      A
# 1552   0.714      B
# 1553   0.394      D
# 1554   0.881      F
# 1555   0.422      G
#
# [1556 rows x 23 columns]

# %% [markdown]
# # Codigos de Exploración

# %% [markdown]
# ### df.shape
# Nos ayuda  a saber la forma o tamaño del dataset.

# %%
df.shape
# Out:
# (1556, 23)

# %% [markdown]
# ### df.columns
# Cuales son los nombres de las columnas

# %%
df.columns
# Out:
# Index(['Index', 'Highest Charting Position', 'Number of Times Charted',
#        'Week of Highest Charting', 'Song Name', 'Streams', 'Artist',
#        'Artist Followers', 'Song ID', 'Genre', 'Release Date', 'Weeks Charted',
#        'Popularity', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
#        'Acousticness', 'Liveness', 'Tempo', 'Duration (ms)', 'Valence',
#        'Chord'],
#       dtype='object')

# %% [markdown]
# ### df.head()
# Nos ayuda a darnos los 5 primeros datos y si le ponemos un numero definido por ejemplo 20 ,
# nos mostrata los primeros 20 datos.

# %%
df.head()
# Out:
#    Index  Highest Charting Position  Number of Times Charted  \
# 0      1                          1                        8
# 1      2                          2                        3
# 2      3                          1                       11
# 3      4                          3                        5
# 4      5                          5                        1
#
#   Week of Highest Charting                          Song Name     Streams  \
# 0   2021-07-23--2021-07-30                            Beggin'  48,633,449
# 1   2021-07-23--2021-07-30          STAY (with Justin Bieber)  47,248,719
# 2   2021-06-25--2021-07-02                           good 4 u  40,162,559
# 3   2021-07-02--2021-07-09                         Bad Habits  37,799,456
# 4   2021-07-23--2021-07-30  INDUSTRY BABY (feat. Jack Harlow)  33,948,454
#
#            Artist Artist Followers                 Song ID  \
# 0        Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# 1   The Kid LAROI          2230022  5HCyWlXZPP0y6Gqq8TgA20
# 2  Olivia Rodrigo          6266514  4ZtFanR9U6ndgddUvNcjcG
# 3      Ed Sheeran         83293380  6PQ88X9TkUIAUIZJHW2upE
# 4       Lil Nas X          5473565  27NovPIUIRrOZoCHxABJwK
#
#                                     Genre  ... Danceability Energy Loudness  \
# 0  ['indie rock italiano', 'italian pop']  ...        0.714    0.8   -4.808
# 1                  ['australian hip hop']  ...        0.591  0.764   -5.484
# 2                                 ['pop']  ...        0.563  0.664   -5.044
# 3                       ['pop', 'uk pop']  ...        0.808  0.897   -3.712
# 4           ['lgbtq+ hip hop', 'pop rap']  ...        0.736  0.704   -7.409
#
#   Speechiness Acousticness Liveness    Tempo Duration (ms) Valence  Chord
# 0      0.0504        0.127    0.359  134.002        211560   0.589      B
# 1      0.0483       0.0383    0.103  169.928        141806   0.478  C#/Db
# 2       0.154        0.335   0.0849  166.928        178147   0.688      A
# 3      0.0348       0.0469    0.364  126.026        231041   0.591      B
# 4      0.0615       0.0203   0.0501  149.995        212000   0.894  D#/Eb
#
# [5 rows x 23 columns]

# %%
df.head(20)
# Out:
#     Index  Highest Charting Position  Number of Times Charted  \
# 0       1                          1                        8
# 1       2                          2                        3
# 2       3                          1                       11
# 3       4                          3                        5
# 4       5                          5                        1
# 5       6                          1                       18
# 6       7                          3                       16
# 7       8                          2                       10
# 8       9                          3                        8
# 9      10                          8                       10
# 10     11                          4                       43
# 11     12                          9                        9
# 12     13                          5                        3
# 13     14                          1                       19
# 14     15                          2                       10
# 15     16                          7                       10
# 16     17                          3                       17
# 17     18                          5                       14
# 18     19                         14                        5
# 19     20                         20                        7
#
#    Week of Highest Charting                                     Song Name  \
# 0    2021-07-23--2021-07-30                                       Beggin'
# 1    2021-07-23--2021-07-30                     STAY (with Justin Bieber)
# 2    2021-06-25--2021-07-02                                      good 4 u
# 3    2021-07-02--2021-07-09                                    Bad Habits
# 4    2021-07-23--2021-07-30             INDUSTRY BABY (feat. Jack Harlow)
# 5    2021-05-07--2021-05-14                MONTERO (Call Me By Your Name)
# 6    2021-05-14--2021-05-21                      Kiss Me More (feat. SZA)
# 7    2021-06-18--2021-06-25                                    Todo De Ti
# 8    2021-06-18--2021-06-25                                      Yonaguni
# 9    2021-07-02--2021-07-09                         I WANNA BE YOUR SLAVE
# 10   2021-05-07--2021-05-14                     Levitating (feat. DaBaby)
# 11   2021-07-02--2021-07-09                                 Qué Más Pues?
# 12   2021-07-09--2021-07-16                           Permission to Dance
# 13   2021-04-02--2021-04-09        Peaches (feat. Daniel Caesar & Giveon)
# 14   2021-05-21--2021-05-28                                        Butter
# 15   2021-05-21--2021-05-28                                       traitor
# 16   2021-05-21--2021-05-28                                       deja vu
# 17   2021-04-23--2021-04-30  Save Your Tears (with Ariana Grande) (Remix)
# 18   2021-07-02--2021-07-09                                      AM Remix
# 19   2021-07-23--2021-07-30                                  Need To Know
#
#        Streams                           Artist Artist Followers  \
# 0   48,633,449                         Måneskin          3377762
# 1   47,248,719                    The Kid LAROI          2230022
# 2   40,162,559                   Olivia Rodrigo          6266514
# 3   37,799,456                       Ed Sheeran         83293380
# 4   33,948,454                        Lil Nas X          5473565
# 5   30,071,134                        Lil Nas X          5473565
# 6   29,356,736                         Doja Cat          8640063
# 7   26,951,613                   Rauw Alejandro          6080597
# 8   25,030,128                        Bad Bunny         36142273
# 9   24,551,591                         Måneskin          3377762
# 10  23,518,010                         Dua Lipa         27142474
# 11  22,405,111          J Balvin, Maria Becerra         29051363
# 12  22,062,812                              BTS         37106176
# 13  20,294,457                    Justin Bieber         48504126
# 14  19,985,713                              BTS         37106176
# 15  19,480,679                   Olivia Rodrigo          6266514
# 16  18,571,755                   Olivia Rodrigo          6266514
# 17  18,053,141                       The Weeknd         35305637
# 18  17,617,965  Nio Garcia, J Balvin, Bad Bunny          2123734
# 19  16,908,917                         Doja Cat          8640063
#
#                    Song ID                                              Genre  \
# 0   3Wrjm47oTz2sjIgck11l5e             ['indie rock italiano', 'italian pop']
# 1   5HCyWlXZPP0y6Gqq8TgA20                             ['australian hip hop']
# 2   4ZtFanR9U6ndgddUvNcjcG                                            ['pop']
# 3   6PQ88X9TkUIAUIZJHW2upE                                  ['pop', 'uk pop']
# 4   27NovPIUIRrOZoCHxABJwK                      ['lgbtq+ hip hop', 'pop rap']
# 5   67BtfxlNbhBmCDR2L2l8qd                      ['lgbtq+ hip hop', 'pop rap']
# 6   748mdHapucXQri7IAO8yFK                               ['dance pop', 'pop']
# 7   4fSIb4hdOQ151TILNsSEaF                ['puerto rican pop', 'trap latino']
# 8   2JPLbjOn0wPCngEot2STUS              ['latin', 'reggaeton', 'trap latino']
# 9   4pt5fDVTg5GhEvEtlz9dKk             ['indie rock italiano', 'italian pop']
# 10  463CkQjx2Zk1yXoBuierM9                     ['dance pop', 'pop', 'uk pop']
# 11  6hf0RpxTbOprT5nnwzkk8e     ['latin', 'reggaeton', 'reggaeton colombiano']
# 12  0LThjFY2iTtNdd4wviwVV2                       ['k-pop', 'k-pop boy group']
# 13  4iJyoBOLtHqaGxP12qzhQI           ['canadian pop', 'pop', 'post-teen pop']
# 14  2bgTY4UwhfBYhGT4HUYStN                       ['k-pop', 'k-pop boy group']
# 15  5CZ40GBx1sQ9agT82CLQCT                                            ['pop']
# 16  6HU7h9RYOaPRFeh0R3UeAr                                            ['pop']
# 17  37BZB0z9T8Xu7U3e65qxFy  ['canadian contemporary r&b', 'canadian pop', ...
# 18  05bfbizlM5AX6Mf1RRyMho              ['latin', 'reggaeton', 'trap latino']
# 19  3Vi5XqYrmQgOYBajMWSvCi                               ['dance pop', 'pop']
#
#     ... Danceability Energy Loudness Speechiness Acousticness Liveness  \
# 0   ...        0.714    0.8   -4.808      0.0504        0.127    0.359
# 1   ...        0.591  0.764   -5.484      0.0483       0.0383    0.103
# 2   ...        0.563  0.664   -5.044       0.154        0.335   0.0849
# 3   ...        0.808  0.897   -3.712      0.0348       0.0469    0.364
# 4   ...        0.736  0.704   -7.409      0.0615       0.0203   0.0501
# 5   ...         0.61  0.508   -6.682       0.152        0.297    0.384
# 6   ...        0.762  0.701   -3.541      0.0286        0.235    0.123
# 7   ...         0.78  0.718   -3.605      0.0506         0.31   0.0932
# 8   ...        0.644  0.648   -4.601       0.118        0.276    0.135
# 9   ...         0.75  0.608   -4.008      0.0387      0.00165    0.178
# 10  ...        0.702  0.825   -3.787      0.0601      0.00883   0.0674
# 11  ...        0.891  0.819   -3.964       0.106       0.0261    0.173
# 12  ...        0.702  0.741    -5.33      0.0427      0.00544    0.337
# 13  ...        0.677  0.696   -6.181       0.119        0.321     0.42
# 14  ...        0.759  0.459   -5.187      0.0948      0.00323   0.0906
# 15  ...         0.38  0.339   -7.885      0.0338        0.691     0.12
# 16  ...        0.442  0.612   -7.222       0.112        0.584     0.37
# 17  ...         0.65  0.825   -4.645      0.0325       0.0215   0.0936
# 18  ...        0.743  0.655   -5.015       0.159        0.114   0.0764
# 19  ...        0.664  0.609   -6.509      0.0707        0.304   0.0926
#
#       Tempo Duration (ms) Valence  Chord
# 0   134.002        211560   0.589      B
# 1   169.928        141806   0.478  C#/Db
# 2   166.928        178147   0.688      A
# 3   126.026        231041   0.591      B
# 4   149.995        212000   0.894  D#/Eb
# 5   178.818        137876   0.758  G#/Ab
# 6   110.968        208867   0.742  G#/Ab
# 7   127.949        199604   0.342  D#/Eb
# 8   179.951        206710    0.44  C#/Db
# 9   132.507        173347   0.958  C#/Db
# 10  102.977        203064   0.915  F#/Gb
# 11  101.968        217773   0.768  G#/Ab
# 12  124.925        187585   0.646      A
# 13    90.03        198082   0.464      C
# 14  109.997        164442   0.695  G#/Ab
# 15  100.607        229227  0.0849  D#/Eb
# 16  180.917        215507   0.178      D
# 17  118.091        191014   0.593      C
# 18  172.031        261335   0.785  F#/Gb
# 19  130.041        210560   0.194  C#/Db
#
# [20 rows x 23 columns]

# %% [markdown]
# ### df.tail
# Nos ayuda a darnos los 5 ultimos datos de la tabla y si ponemos ente los parentesis un 50 nos dara los 50 ultimos

# %%
df.tail()
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 1551   1552                        195                        1
# 1552   1553                        196                        1
# 1553   1554                        197                        1
# 1554   1555                        198                        1
# 1555   1556                        199                        1
#
#      Week of Highest Charting                           Song Name    Streams  \
# 1551   2019-12-27--2020-01-03                           New Rules  4,630,675
# 1552   2019-12-27--2020-01-03                  Cheirosa - Ao Vivo  4,623,030
# 1553   2019-12-27--2020-01-03           Havana (feat. Young Thug)  4,620,876
# 1554   2019-12-27--2020-01-03          Surtada - Remix Brega Funk  4,607,385
# 1555   2019-12-27--2020-01-03  Lover (Remix) [feat. Shawn Mendes]  4,595,450
#
#                              Artist Artist Followers                 Song ID  \
# 1551                       Dua Lipa         27167675  2ekn2ttSfGqwhhate0LSR0
# 1552                 Jorge & Mateus         15019109  2PWjKmjyTZeDpmOUa3a5da
# 1553                 Camila Cabello         22698747  1rfofaqEpACxVEHIZBJe6W
# 1554  Dadá Boladão, Tati Zaqui, OIK           208630  5F8ffc8KWKNawllr5WsW0r
# 1555                   Taylor Swift         42227614  3i9UVldZOE0aD0JnyfAZZ0
#
#                                                   Genre  ... Danceability  \
# 1551                     ['dance pop', 'pop', 'uk pop']  ...        0.762
# 1552           ['sertanejo', 'sertanejo universitario']  ...        0.528
# 1553  ['dance pop', 'electropop', 'pop', 'post-teen ...  ...        0.765
# 1554                     ['brega funk', 'funk carioca']  ...        0.832
# 1555                           ['pop', 'post-teen pop']  ...        0.448
#
#      Energy Loudness Speechiness Acousticness Liveness    Tempo Duration (ms)  \
# 1551    0.7   -6.021      0.0694      0.00261    0.153  116.073        209320
# 1552   0.87   -3.123      0.0851         0.24    0.333   152.37        181930
# 1553  0.523   -4.333        0.03        0.184    0.132  104.988        217307
# 1554   0.55   -7.026      0.0587        0.249    0.182  154.064        152784
# 1555  0.603   -7.176       0.064        0.433   0.0862  205.272        221307
#
#      Valence Chord
# 1551   0.608     A
# 1552   0.714     B
# 1553   0.394     D
# 1554   0.881     F
# 1555   0.422     G
#
# [5 rows x 23 columns]

# %%
df.tail(50)
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 1506   1507                        155                        1
# 1507   1508                        157                        1
# 1508   1509                        167                        1
# 1509   1510                        168                        1
# 1510   1511                         87                        1
# 1511   1512                         90                        1
# 1512   1513                        107                        1
# 1513   1514                        111                        1
# 1514   1515                        119                        1
# 1515   1516                         83                        3
# 1516   1517                        111                        3
# 1517   1518                        102                        3
# 1518   1519                        161                        1
# 1519   1520                        166                        1
# 1520   1521                        131                        3
# 1521   1522                        138                        3
# 1522   1523                        176                        1
# 1523   1524                        182                        2
# 1524   1525                        187                        1
# 1525   1526                        140                        3
# 1526   1527                        177                        3
3i9UVldZOE0aD0JnyfAZZ0
#
#                                                   Genre  ... Danceability  \
# 1506             ['german cloud rap', 'german hip hop']  ...        0.791
# 1507               ['hip hop', 'pittsburgh rap', 'rap']  ...        0.739
# 1508  ['francoton', 'french hip hop', 'pop urbaine',...  ...        0.916
# 1509  ['francoton', 'french hip hop', 'pop urbaine',...  ...        0.776
# 1510              ['dance pop', 'pop', 'post-teen pop']  ...        0.695
# 1511              ['dance pop', 'pop', 'post-teen pop']  ...        0.784
# 1512              ['dance pop', 'pop', 'post-teen pop']  ...        0.873
# 1513              ['dance pop', 'pop', 'post-teen pop']  ...        0.724
# 1514              ['dance pop', 'pop', 'post-teen pop']  ...        0.695
# 1515                                            ['pop']  ...        0.665
# 1516              ['dance pop', 'pop', 'post-teen pop']  ...        0.591
# 1517                                                 []  ...        0.323
# 1518              ['dance pop', 'pop', 'post-teen pop']  ...        0.826
# 1519              ['dance pop', 'pop', 'post-teen pop']  ...        0.583
# 1520  ['melodic rap', 'rap', 'rap conscient', 'trap'...  ...        0.748
# 1521                  ['dfw rap', 'melodic rap', 'rap']  ...        0.499
# 1522                     ['melodic rap', 'rap', 'trap']  ...        0.757
# 1523                     ['melodic rap', 'rap', 'trap']  ...        0.886
# 1524    ['houston rap', 'pop', 'pop rap', 'trap queen']  ...        0.785
# 1525  ['dance pop', 'edm', 'pop', 'pop dance', 'post...  ...        0.674
# 1526                     ['melodic rap', 'rap', 'trap']  ...        0.802
# 1527         ['latin', 'latin pop', 'puerto rican pop']  ...        0.826
# 1528              ['dance pop', 'pop', 'post-teen pop']  ...        0.855
# 1529              ['dance pop', 'pop', 'post-teen pop']  ...        0.691
# 1530  ['dance pop', 'pop', 'pop dance', 'post-teen p...  ...        0.697
# 1531  ['dance pop', 'edm', 'electronic trap', 'pop',...  ...        0.842
# 1532  ['dance pop', 'edm', 'electropop', 'pop', 'pop...  ...        0.584
# 1533                                    ['rap', 'trap']  ...        0.859
# 1534                                    ['rap', 'trap']  ...         0.75
# 1535                                    ['rap', 'trap']  ...        0.643
# 1536  ['gangster rap', 'hip hop', 'pop rap', 'rap', ...  ...        0.773
# 1537                                       ['cali rap']  ...        0.746
# 1538                                                     ...
# 1539                                 ['german hip hop']  ...        0.941
# 1540              ['dance pop', 'pop', 'post-teen pop']  ...         0.77
# 1541  ['dance pop', 'edm', 'electro house', 'house',...  ...        0.791
# 1542  ['latin', 'puerto rican pop', 'reggaeton', 'tr...  ...        0.695
# 1543                              ['electropop', 'pop']  ...        0.619
# 1544                                    ['rap', 'trap']  ...        0.594
# 1545                               ['dance pop', 'pop']  ...        0.689
# 1546                                    ['rap', 'trap']  ...        0.413
# 1547  ['funk carioca', 'funk pop', 'pagode baiano', ...  ...        0.826
# 1548                      ['lgbtq+ hip hop', 'pop rap']  ...        0.878
# 1549                     ['chicago rap', 'melodic rap']  ...        0.635
# 1550  ['francoton', 'french hip hop', 'pop urbaine',...  ...        0.932
# 1551                     ['dance pop', 'pop', 'uk pop']  ...        0.762
# 1552           ['sertanejo', 'sertanejo universitario']  ...        0.528
# 1553  ['dance pop', 'electropop', 'pop', 'post-teen ...  ...        0.765
# 1554                     ['brega funk', 'funk carioca']  ...        0.832
# 1555                           ['pop', 'post-teen pop']  ...        0.448
#
#      Energy Loudness Speechiness Acousticness Liveness    Tempo Duration (ms)  \
#
# 1551    0.7   -6.021      0.0694      0.00261    0.153  116.073        209320
# 1552   0.87   -3.123      0.0851         0.24    0.333   152.37        181930
# 1553  0.523   -4.333        0.03        0.184    0.132  104.988        217307
# 1554   0.55   -7.026      0.0587        0.249    0.182  154.064        152784
# 1555  0.603   -7.176       0.064        0.433   0.0862  205.272        221307
#
#      Valence  Chord
# 1506   0.443      C
# 1507   0.542      C
# 1508     0.7  C#/Db
# 1509   0.551      E
# 1510    0.38  A#/Bb
# 1511   0.465  C#/Db
# 1512   0.871  D#/Eb
# 1513   0.328      G
# 1514    0.62  G#/Ab
# 1515   0.669  C#/Db
# 1516   0.392      E
# 1517   0.274  A#/Bb
# 1518   0.475      D
# 1519    0.31  A#/Bb
# 1520   0.726  A#/Bb
# 1521   0.272  C#/Db
# 1522   0.574  C#/Db
# 1523   0.408      E
# 1524   0.488  C#/Db
# 1525   0.234      A
# 1526   0.613  A#/Bb
# 1527   0.761      B
# 1528   0.842      F
# 1529   0.534      B
# 1530   0.603  C#/Db
# 1531   0.617  G#/Ab
# 1532   0.374      B
# 1533   0.568      G
# 1534   0.673      D
# 1535   0.195      A
# 1536   0.497      A
# 1537   0.523      A
# 1538
# 1539   0.683  A#/Bb
# 1540   0.385  G#/Ab
# 1541   0.592      A
# 1542   0.781      D
# 1543   0.498      G
# 1544   0.472      D
# 1545   0.209  G#/Ab
# 1546  0.0676      C
# 1547   0.605  C#/Db
# 1548   0.639  F#/Gb
# 1549   0.383      G
# 1550   0.933  A#/Bb
# 1551   0.608      A
# 1552   0.714      B
# 1553   0.394      D
# 1554   0.881      F
# 1555   0.422      G
#
# [50 rows x 23 columns]

# %% [markdown]
# ### df.dtypes
# Podemos ver los dtypes de todas nuestras columnas accediendo a esa propiedad:

# %%
df.dtypes
# Out:
# Index                         int64
# Highest Charting Position     int64
# Number of Times Charted       int64
# Week of Highest Charting     object
# Song Name                    object
# Streams                      object
# Artist                       object
# Artist Followers             object
# Song ID                      object
# Genre                        object
# Release Date                 object
# Weeks Charted                object
# Popularity                   object
# Danceability                 object
# Energy                       object
# Loudness                     object
# Speechiness                  object
# Acousticness                 object
# Liveness                     object
# Tempo                        object
# Duration (ms)                object
# Valence                      object
# Chord                        object
# dtype: object

# %% [markdown]
# ### df.info
# También podemos usar la función info del DataFrame para ver más información sobre las columnas. Por ejemplo, el número de valores no nulos que hay en cada una.

# %%
df.info
# Out:
# <bound method DataFrame.info of       Index  Highest Charting Position  Number of Times Charted  \
# 0         1                          1                        8
# 1         2                          2                        3
# 2         3                          1                       11
# 3         4                          3                        5
# 4         5                          5                        1
# ...     ...                        ...                      ...
# 1551   1552                        195                        1
# 1552   1553                        196                        1
# 1553   1554                        197                        1
# 1554   1555                        198                        1
# 1555   1556                        199                        1
#
#      Week of Highest Charting                           Song Name     Streams  \
# 0      2021-07-23--2021-07-30                             Beggin'  48,633,449
# 1      2021-07-23--2021-07-30           STAY (with Justin Bieber)  47,248,719
# 2      2021-06-25--2021-07-02                            good 4 u  40,162,559
# 3      2021-07-02--2021-07-09                          Bad Habits  37,799,456
# 4      2021-07-23--2021-07-30   INDUSTRY BABY (feat. Jack Harlow)  33,948,454
# ...                       ...                                 ...         ...
# 1551   2019-12-27--2020-01-03                           New Rules   4,630,675
# 1552   2019-12-27--2020-01-03                  Cheirosa - Ao Vivo   4,623,030
# 1553   2019-12-27--2020-01-03           Havana (feat. Young Thug)   4,620,876
# 1554   2019-12-27--2020-01-03          Surtada - Remix Brega Funk   4,607,385
# 1555   2019-12-27--2020-01-03  Lover (Remix) [feat. Shawn Mendes]   4,595,450
#
#                              Artist Artist Followers                 Song ID  \
# 0                          Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# 1                     The Kid LAROI          2230022  5HCyWlXZPP0y6Gqq8TgA20
# 2                    Olivia Rodrigo          6266514  4ZtFanR9U6ndgddUvNcjcG
# 3                        Ed Sheeran         83293380  6PQ88X9TkUIAUIZJHW2upE
# 4                         Lil Nas X          5473565  27NovPIUIRrOZoCHxABJwK
# ...                             ...              ...                     ...
# 1551                       Dua Lipa         27167675  2ekn2ttSfGqwhhate0LSR0
# 1552                 Jorge & Mateus         15019109  2PWjKmjyTZeDpmOUa3a5da
# 1553                 Camila Cabello         22698747  1rfofaqEpACxVEHIZBJe6W
# 1554  Dadá Boladão, Tati Zaqui, OIK           208630  5F8ffc8KWKNawllr5WsW0r
# 1555                   Taylor Swift         42227614  3i9UVldZOE0aD0JnyfAZZ0
#
#                                                   Genre  ... Danceability  \
# 0                ['indie rock italiano', 'italian pop']  ...        0.714
# 1                                ['australian hip hop']  ...        0.591
# 2                                               ['pop']  ...        0.563
# 3                                     ['pop', 'uk pop']  ...        0.808
# 4                         ['lgbtq+ hip hop', 'pop rap']  ...        0.736
# ...                                                 ...  ...          ...
# 1551                     ['dance pop', 'pop', 'uk pop']  ...        0.762
# 1552           ['sertanejo', 'sertanejo universitario']  ...        0.528
# 1553  ['dance pop', 'electropop', 'pop', 'post-teen ...  ...        0.765
# 1554                     ['brega funk', 'funk carioca']  ...        0.832
# 1555                           ['pop', 'post-teen pop']  ...        0.448
#
#      Energy Loudness Speechiness Acousticness Liveness    Tempo Duration (ms)  \
# 0       0.8   -4.808      0.0504        0.127    0.359  134.002        211560
# 1     0.764   -5.484      0.0483       0.0383    0.103  169.928        141806
# 2     0.664   -5.044       0.154        0.335   0.0849  166.928        178147
# 3     0.897   -3.712      0.0348       0.0469    0.364  126.026        231041
# 4     0.704   -7.409      0.0615       0.0203   0.0501  149.995        212000
# ...     ...      ...         ...          ...      ...      ...           ...
# 1551    0.7   -6.021      0.0694      0.00261    0.153  116.073        209320
# 1552   0.87   -3.123      0.0851         0.24    0.333   152.37        181930
# 1553  0.523   -4.333        0.03        0.184    0.132  104.988        217307
# 1554   0.55   -7.026      0.0587        0.249    0.182  154.064        152784
# 1555  0.603   -7.176       0.064        0.433   0.0862  205.272        221307
#
#      Valence  Chord
# 0      0.589      B
# 1      0.478  C#/Db
# 2      0.688      A
# 3      0.591      B
# 4      0.894  D#/Eb
# ...      ...    ...
# 1551   0.608      A
# 1552   0.714      B
# 1553   0.394      D
# 1554   0.881      F
# 1555   0.422      G
#
# [1556 rows x 23 columns]>

# %% [markdown]
# ### df.describe()
# Una forma descriptiva para que nos de los datos

# %%
df.describe()
# Out:
#              Index  Highest Charting Position  Number of Times Charted
# count  1556.000000                1556.000000              1556.000000
# mean    778.500000                  87.744216                10.668380
# std     449.322824                  58.147225                16.360546
# min       1.000000                   1.000000                 1.000000
# 25%     389.750000                  37.000000                 1.000000
# 50%     778.500000                  80.000000                 4.000000
# 75%    1167.250000                 137.000000                12.000000
# max    1556.000000                 200.000000               142.000000

# %% [markdown]
# Boxplots
# 1. Objetivos:
# - Aprender a graficar e interpretar boxplots utilizando Seaborn
# - Aprender a lidiar con valores atípicos usando IQR-Score
# 2. Desarrollo:
# Los boxplots son una manera de visualizar la distribución de nuestros datos usando percentiles. Vamos a utilizar una librería de visualización de datos llamada Seaborn que hace muy sencilla la creación de boxplots.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../Datasets/spotify_dataset.csv')

# %%
df.shape
# Out:
# (1556, 23)

# %%
plt.boxplot(df['Highest Charting Position'],labels=['Highest Charting Position'])
plt.show()
# Out:
# C:\Users\edenq\AppData\Local\Temp\ipykernel_9168\2423513922.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(df['Highest Charting Position'],labels=['Highest Charting Position'])

# %% [markdown]
# # Desviación estándar
#
# 1. Objetivos:
# - Aprender cómo se calcula la desviación estándar
# - Aprender a usar `pandas` para calcularla
#
# ---
#
# 2. Desarrollo:
#
# Para obtener la desviación estándar se llevan a cabo los siguientes pasos:
#
# 1. Primero se obtiene el promedio de nuestros datos.
# 1. Después sacamos todas las diferencias entre cada valor de nuesrto conjunto y nuestro valor típico.
# 1. Después elevamos todos los resultados al cuadrado.
# 1. Luego se suman todos estos valores.
# 1. Luego se dividen entre la cantidad de valores - 1.
# 1. Finalmente se saca la raíz cuadrada del valor resultante.
#
# pandas tiene un método con el que podemos calcular la desviación estándar rápidamente:

# %%
df['Highest Charting Position'].mean()
# Out:
# 87.74421593830334

# %%
df['Highest Charting Position'].std
# Out:
# <bound method Series.std of 0         1
# 1         2
# 2         1
# 3         3
# 4         5
#        ...
# 1551    195
# 1552    196
# 1553    197
# 1554    198
# 1555    199
# Name: Highest Charting Position, Length: 1556, dtype: int64>

# %% [markdown]
# Entre mayor sea nuestro resultado quiere decir que nuestros datos están más dispersos (es decir, hay muchos datos que se alejan de nuestro valor típico); entre menor sea el resultado quiere decir que nuestros datos están menos dispersos (es decir, están más cerca de nuestro valor típico).
#
# Obviamente hay que tomar en cuenta el rango de nuestros valores para determinar si nuestra desviación estándar es pequeña o grande. Por ejemplo, una desviación estándar de 10 es muy pequeña si nuestros valores tienen un rango de 1 000 000. En cambio, una desviación estándar de 10 es mucho mayor si nuestros valores tienen un rango de 40.

# %% [markdown]
# # Cambio de Nombre a las Columnas
#
# 1. Objetivos:
# - Utilizar un diccionario para el cambio de los nombres de las columnas
# - Cambiar los nombres de las columnas
#
# ---
#
# 2. Desarrollo:
#
# Para obtener cambiar los nombres de las columnas se llevan a cabo los siguientes pasos:
#
# 1. Abrir el archivo CSV.
# 2. Verificar los nombres actuales de las columnas.
# 3. Cambiar los nombres de las columnas.
# 4. Asignar una lista de nombres nuevos.
# 5. Usar un diccionario.
# 6. Renombrar usando una función.
# 7. Verificar los cambios.

# %%
df
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 0         1                          1                        8
# 1         2                          2                        3
# 2         3                          1                       11
# 3         4                          3                        5
# 4         5                          5                        1
# ...     ...                        ...                      ...
# 1551   1552                        195                        1
# 1552   1553                        196                        1
# 1553   1554                        197                        1
# 1554   1555                        198                        1
# 1555   1556                        199                        1
#
#      Week of Highest Charting                           Song Name     Streams  \
# 0      2021-07-23--2021-07-30                             Beggin'  48,633,449
# 1      2021-07-23--2021-07-30           STAY (with Justin Bieber)  47,248,719
# 2      2021-06-25--2021-07-02                            good 4 u  40,162,559
# 3      2021-07-02--2021-07-09                          Bad Habits  37,799,456
# 4      2021-07-23--2021-07-30   INDUSTRY BABY (feat. Jack Harlow)  33,948,454
# ...                       ...                                 ...         ...
# 1551   2019-12-27--2020-01-03                           New Rules   4,630,675
# 1552   2019-12-27--2020-01-03                  Cheirosa - Ao Vivo   4,623,030
# 1553   2019-12-27--2020-01-03           Havana (feat. Young Thug)   4,620,876
# 1554   2019-12-27--2020-01-03          Surtada - Remix Brega Funk   4,607,385
# 1555   2019-12-27--2020-01-03  Lover (Remix) [feat. Shawn Mendes]   4,595,450
#
#                              Artist Artist Followers                 Song ID  \
# 0                          Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# 1                     The Kid LAROI          2230022  5HCyWlXZPP0y6Gqq8TgA20
# 2                    Olivia Rodrigo          6266514  4ZtFanR9U6ndgddUvNcjcG
# 3                        Ed Sheeran         83293380  6PQ88X9TkUIAUIZJHW2upE
# 4                         Lil Nas X          5473565  27NovPIUIRrOZoCHxABJwK
# ...                             ...              ...                     ...
# 1551                       Dua Lipa         27167675  2ekn2ttSfGqwhhate0LSR0
# 1552                 Jorge & Mateus         15019109  2PWjKmjyTZeDpmOUa3a5da
# 1553                 Camila Cabello         22698747  1rfofaqEpACxVEHIZBJe6W
# 1554  Dadá Boladão, Tati Zaqui, OIK           208630  5F8ffc8KWKNawllr5WsW0r
# 1555                   Taylor Swift         42227614  3i9UVldZOE0aD0JnyfAZZ0
#
#                                                   Genre  ... Danceability  \
# 0                ['indie rock italiano', 'italian pop']  ...        0.714
# 1                                ['australian hip hop']  ...        0.591
# 2                                               ['pop']  ...        0.563
# 3                                     ['pop', 'uk pop']  ...        0.808
# 4                         ['lgbtq+ hip hop', 'pop rap']  ...        0.736
# ...                                                 ...  ...          ...
# 1551                     ['dance pop', 'pop', 'uk pop']  ...        0.762
# 1552           ['sertanejo', 'sertanejo universitario']  ...        0.528
# 1553  ['dance pop', 'electropop', 'pop', 'post-teen ...  ...        0.765
# 1554                     ['brega funk', 'funk carioca']  ...        0.832
# 1555                           ['pop', 'post-teen pop']  ...        0.448
#
#      Energy Loudness Speechiness Acousticness Liveness    Tempo Duration (ms)  \
# 0       0.8   -4.808      0.0504        0.127    0.359  134.002        211560
# 1     0.764   -5.484      0.0483       0.0383    0.103  169.928        141806
# 2     0.664   -5.044       0.154        0.335   0.0849  166.928        178147
# 3     0.897   -3.712      0.0348       0.0469    0.364  126.026        231041
# 4     0.704   -7.409      0.0615       0.0203   0.0501  149.995        212000
# ...     ...      ...         ...          ...      ...      ...           ...
# 1551    0.7   -6.021      0.0694      0.00261    0.153  116.073        209320
# 1552   0.87   -3.123      0.0851         0.24    0.333   152.37        181930
# 1553  0.523   -4.333        0.03        0.184    0.132  104.988        217307
# 1554   0.55   -7.026      0.0587        0.249    0.182  154.064        152784
# 1555  0.603   -7.176       0.064        0.433   0.0862  205.272        221307
#
#      Valence  Chord
# 0      0.589      B
# 1      0.478  C#/Db
# 2      0.688      A
# 3      0.591      B
# 4      0.894  D#/Eb
# ...      ...    ...
# 1551   0.608      A
# 1552   0.714      B
# 1553   0.394      D
# 1554   0.881      F
# 1555   0.422      G
#
# [1556 rows x 23 columns]

# %%
df2=df.rename({'Index':'Indice','Highest Charting Position':'Posición más alta en los gráficos','Number of Times Charted':'Número de veces registradas','Week of Highest Charting':'Semana de gráficos más altos','Song Name':'Nombre de la cancion','Streams':'Corrientes','Artist':'Artista','Artist Followers':'Seguidores del Artista','Song ID':'ID Cancion','Genre':'Genero','Danceability':'Bailabilidad','Energy':'Energia','Loudness':'Volumen','Speechiness':'habla','Acousticness':'Acústica','Liveness':'vivacidad','Tempo':'Tempo','Duration (ms)':'Duracion (ms)','Valence':'Valencia','Chord':'Acorde'}, axis=1)

# %%
df2
# Out:
#       Indice  Posición más alta en los gráficos  Número de veces registradas  \
# 0          1                                  1                            8
# 1          2                                  2                            3
# 2          3                                  1                           11
# 3          4                                  3                            5
# 4          5                                  5                            1
# ...      ...                                ...                          ...
# 1551    1552                                195                            1
# 1552    1553                                196                            1
# 1553    1554                                197                            1
# 1554    1555                                198                            1
# 1555    1556                                199                            1
#
#      Semana de gráficos más altos                Nombre de la cancion  \
# 0          2021-07-23--2021-07-30                             Beggin'
# 1          2021-07-23--2021-07-30           STAY (with Justin Bieber)
# 2          2021-06-25--2021-07-02                            good 4 u
# 3          2021-07-02--2021-07-09                          Bad Habits
# 4          2021-07-23--2021-07-30   INDUSTRY BABY (feat. Jack Harlow)
# ...                           ...                                 ...
# 1551       2019-12-27--2020-01-03                           New Rules
# 1552       2019-12-27--2020-01-03                  Cheirosa - Ao Vivo
# 1553       2019-12-27--2020-01-03           Havana (feat. Young Thug)
# 1554       2019-12-27--2020-01-03          Surtada - Remix Brega Funk
# 1555       2019-12-27--2020-01-03  Lover (Remix) [feat. Shawn Mendes]
#
#       Corrientes                        Artista Seguidores del Artista  \
# 0     48,633,449                       Måneskin                3377762
# 1     47,248,719                  The Kid LAROI                2230022
# 2     40,162,559                 Olivia Rodrigo                6266514
# 3     37,799,456                     Ed Sheeran               83293380
# 4     33,948,454                      Lil Nas X                5473565
# ...          ...                            ...                    ...
# 1551   4,630,675                       Dua Lipa               27167675
# 1552   4,623,030                 Jorge & Mateus               15019109
# 1553   4,620,876                 Camila Cabello               22698747
# 1554   4,607,385  Dadá Boladão, Tati Zaqui, OIK                 208630
# 1555   4,595,450                   Taylor Swift               42227614
#
#                   ID Cancion  \
# 0     3Wrjm47oTz2sjIgck11l5e
# 1     5HCyWlXZPP0y6Gqq8TgA20
# 2     4ZtFanR9U6ndgddUvNcjcG
# 3     6PQ88X9TkUIAUIZJHW2upE
# 4     27NovPIUIRrOZoCHxABJwK
# ...                      ...
# 1551  2ekn2ttSfGqwhhate0LSR0
# 1552  2PWjKmjyTZeDpmOUa3a5da
# 1553  1rfofaqEpACxVEHIZBJe6W
# 1554  5F8ffc8KWKNawllr5WsW0r
# 1555  3i9UVldZOE0aD0JnyfAZZ0
#
#                                                  Genero  ... Bailabilidad  \
# 0                ['indie rock italiano', 'italian pop']  ...        0.714
# 1                                ['australian hip hop']  ...        0.591
# 2                                               ['pop']  ...        0.563
# 3                                     ['pop', 'uk pop']  ...        0.808
# 4                         ['lgbtq+ hip hop', 'pop rap']  ...        0.736
# ...                                                 ...  ...          ...
# 1551                     ['dance pop', 'pop', 'uk pop']  ...        0.762
# 1552           ['sertanejo', 'sertanejo universitario']  ...        0.528
# 1553  ['dance pop', 'electropop', 'pop', 'post-teen ...  ...        0.765
# 1554                     ['brega funk', 'funk carioca']  ...        0.832
# 1555                           ['pop', 'post-teen pop']  ...        0.448
#
#      Energia Volumen   habla Acústica vivacidad    Tempo Duracion (ms)  \
# 0        0.8  -4.808  0.0504    0.127     0.359  134.002        211560
# 1      0.764  -5.484  0.0483   0.0383     0.103  169.928        141806
# 2      0.664  -5.044   0.154    0.335    0.0849  166.928        178147
# 3      0.897  -3.712  0.0348   0.0469     0.364  126.026        231041
# 4      0.704  -7.409  0.0615   0.0203    0.0501  149.995        212000
# ...      ...     ...     ...      ...       ...      ...           ...
# 1551     0.7  -6.021  0.0694  0.00261     0.153  116.073        209320
# 1552    0.87  -3.123  0.0851     0.24     0.333   152.37        181930
# 1553   0.523  -4.333    0.03    0.184     0.132  104.988        217307
# 1554    0.55  -7.026  0.0587    0.249     0.182  154.064        152784
# 1555   0.603  -7.176   0.064    0.433    0.0862  205.272        221307
#
#      Valencia Acorde
# 0       0.589      B
# 1       0.478  C#/Db
# 2       0.688      A
# 3       0.591      B
# 4       0.894  D#/Eb
# ...       ...    ...
# 1551    0.608      A
# 1552    0.714      B
# 1553    0.394      D
# 1554    0.881      F
# 1555    0.422      G
#
# [1556 rows x 23 columns]

# %% [markdown]
# # Quitado de NanS
# 1. Objetivos:
# - En este apartado del dataset quitaremos los datos NaNs que tiene en la informacion del Dataset.
#
# 2. Pasos para la eliminacion de los NaNs.
#
# - Identificar valores NaN.
# - Eliminar los valores NaN.
# - Eliminar filas con NaN.
# - Eliminar columnas con NaN.
# - Verificar los cambios.

# %%
df_limpiar = df2.copy()

# %%
df_limpiar
# Out:
#       Indice  Posición más alta en los gráficos  Número de veces registradas  \
# 0          1                                  1                            8
# 1          2                                  2                            3
# 2          3                                  1                           11
# 3          4                                  3                            5
# 4          5                                  5                            1
# ...      ...                                ...                          ...
# 1551    1552                                195                            1
# 1552    1553                                196                            1
# 1553    1554                                197                            1
# 1554    1555                                198                            1
# 1555    1556                                199                            1
#
#      Semana de gráficos más altos                Nombre de la cancion  \
# 0          2021-07-23--2021-07-30                             Beggin'
# 1          2021-07-23--2021-07-30           STAY (with Justin Bieber)
# 2          2021-06-25--2021-07-02                            good 4 u
# 3          2021-07-02--2021-07-09                          Bad Habits
# 4          2021-07-23--2021-07-30   INDUSTRY BABY (feat. Jack Harlow)
# ...                           ...                                 ...
# 1551       2019-12-27--2020-01-03                           New Rules
# 1552       2019-12-27--2020-01-03                  Cheirosa - Ao Vivo
# 1553       2019-12-27--2020-01-03           Havana (feat. Young Thug)
# 1554       2019-12-27--2020-01-03          Surtada - Remix Brega Funk
# 1555       2019-12-27--2020-01-03  Lover (Remix) [feat. Shawn Mendes]
#
#       Corrientes                        Artista Seguidores del Artista  \
# 0     48,633,449                       Måneskin                3377762
# 1     47,248,719                  The Kid LAROI                2230022
# 2     40,162,559                 Olivia Rodrigo                6266514
# 3     37,799,456                     Ed Sheeran               83293380
# 4     33,948,454                      Lil Nas X                5473565
# ...          ...                            ...                    ...
# 1551   4,630,675                       Dua Lipa               27167675
# 1552   4,623,030                 Jorge & Mateus               15019109
# 1553   4,620,876                 Camila Cabello               22698747
# 1554   4,607,385  Dadá Boladão, Tati Zaqui, OIK                 208630
# 1555   4,595,450                   Taylor Swift               42227614
#
#                   ID Cancion  \
# 0     3Wrjm47oTz2sjIgck11l5e
# 1     5HCyWlXZPP0y6Gqq8TgA20
# 2     4ZtFanR9U6ndgddUvNcjcG
# 3     6PQ88X9TkUIAUIZJHW2upE
# 4     27NovPIUIRrOZoCHxABJwK
# ...                      ...
# 1551  2ekn2ttSfGqwhhate0LSR0
# 1552  2PWjKmjyTZeDpmOUa3a5da
# 1553  1rfofaqEpACxVEHIZBJe6W
# 1554  5F8ffc8KWKNawllr5WsW0r
# 1555  3i9UVldZOE0aD0JnyfAZZ0
#
#                                                  Genero  ... Bailabilidad  \
# 0                ['indie rock italiano', 'italian pop']  ...        0.714
# 1                                ['australian hip hop']  ...        0.591
# 2                                               ['pop']  ...        0.563
# 3                                     ['pop', 'uk pop']  ...        0.808
# 4                         ['lgbtq+ hip hop', 'pop rap']  ...        0.736
# ...                                                 ...  ...          ...
# 1551                     ['dance pop', 'pop', 'uk pop']  ...        0.762
# 1552           ['sertanejo', 'sertanejo universitario']  ...        0.528
# 1553  ['dance pop', 'electropop', 'pop', 'post-teen ...  ...        0.765
# 1554                     ['brega funk', 'funk carioca']  ...        0.832
# 1555                           ['pop', 'post-teen pop']  ...        0.448
#
#      Energia Volumen   habla Acústica vivacidad    Tempo Duracion (ms)  \
# 0        0.8  -4.808  0.0504    0.127     0.359  134.002        211560
# 1      0.764  -5.484  0.0483   0.0383     0.103  169.928        141806
# 2      0.664  -5.044   0.154    0.335    0.0849  166.928        178147
# 3      0.897  -3.712  0.0348   0.0469     0.364  126.026        231041
# 4      0.704  -7.409  0.0615   0.0203    0.0501  149.995        212000
# ...      ...     ...     ...      ...       ...      ...           ...
# 1551     0.7  -6.021  0.0694  0.00261     0.153  116.073        209320
# 1552    0.87  -3.123  0.0851     0.24     0.333   152.37        181930
# 1553   0.523  -4.333    0.03    0.184     0.132  104.988        217307
# 1554    0.55  -7.026  0.0587    0.249     0.182  154.064        152784
# 1555   0.603  -7.176   0.064    0.433    0.0862  205.272        221307
#
#      Valencia Acorde
# 0       0.589      B
# 1       0.478  C#/Db
# 2       0.688      A
# 3       0.591      B
# 4       0.894  D#/Eb
# ...       ...    ...
# 1551    0.608      A
# 1552    0.714      B
# 1553    0.394      D
# 1554    0.881      F
# 1555    0.422      G
#
# [1556 rows x 23 columns]

# %%
import numpy as np

# %%
df_limpiar['...'] =np.nan

# %%
df_limpiar
# Out:
#       Indice  Posición más alta en los gráficos  Número de veces registradas  \
# 0          1                                  1                            8
# 1          2                                  2                            3
# 2          3                                  1                           11
# 3          4                                  3                            5
# 4          5                                  5                            1
# ...      ...                                ...                          ...
# 1551    1552                                195                            1
# 1552    1553                                196                            1
# 1553    1554                                197                            1
# 1554    1555                                198                            1
# 1555    1556                                199                            1
#
#      Semana de gráficos más altos                Nombre de la cancion  \
# 0          2021-07-23--2021-07-30                             Beggin'
# 1          2021-07-23--2021-07-30           STAY (with Justin Bieber)
# 2          2021-06-25--2021-07-02                            good 4 u
# 3          2021-07-02--2021-07-09                          Bad Habits
# 4          2021-07-23--2021-07-30   INDUSTRY BABY (feat. Jack Harlow)
# ...                           ...                                 ...
# 1551       2019-12-27--2020-01-03                           New Rules
# 1552       2019-12-27--2020-01-03                  Cheirosa - Ao Vivo
# 1553       2019-12-27--2020-01-03           Havana (feat. Young Thug)
# 1554       2019-12-27--2020-01-03          Surtada - Remix Brega Funk
# 1555       2019-12-27--2020-01-03  Lover (Remix) [feat. Shawn Mendes]
#
#       Corrientes                        Artista Seguidores del Artista  \
# 0     48,633,449                       Måneskin                3377762
# 1     47,248,719                  The Kid LAROI                2230022
# 2     40,162,559                 Olivia Rodrigo                6266514
# 3     37,799,456                     Ed Sheeran               83293380
# 4     33,948,454                      Lil Nas X                5473565
# ...          ...                            ...                    ...
# 1551   4,630,675                       Dua Lipa               27167675
# 1552   4,623,030                 Jorge & Mateus               15019109
# 1553   4,620,876                 Camila Cabello               22698747
# 1554   4,607,385  Dadá Boladão, Tati Zaqui, OIK                 208630
# 1555   4,595,450                   Taylor Swift               42227614
#
#                   ID Cancion  \
# 0     3Wrjm47oTz2sjIgck11l5e
# 1     5HCyWlXZPP0y6Gqq8TgA20
# 2     4ZtFanR9U6ndgddUvNcjcG
# 3     6PQ88X9TkUIAUIZJHW2upE
# 4     27NovPIUIRrOZoCHxABJwK
# ...                      ...
# 1551  2ekn2ttSfGqwhhate0LSR0
# 1552  2PWjKmjyTZeDpmOUa3a5da
# 1553  1rfofaqEpACxVEHIZBJe6W
# 1554  5F8ffc8KWKNawllr5WsW0r
# 1555  3i9UVldZOE0aD0JnyfAZZ0
#
#                                                  Genero  ... Energia Volumen  \
# 0                ['indie rock italiano', 'italian pop']  ...     0.8  -4.808
# 1                                ['australian hip hop']  ...   0.764  -5.484
# 2                                               ['pop']  ...   0.664  -5.044
# 3                                     ['pop', 'uk pop']  ...   0.897  -3.712
# 4                         ['lgbtq+ hip hop', 'pop rap']  ...   0.704  -7.409
# ...                                                 ...  ...     ...     ...
# 1551                     ['dance pop', 'pop', 'uk pop']  ...     0.7  -6.021
# 1552           ['sertanejo', 'sertanejo universitario']  ...    0.87  -3.123
# 1553  ['dance pop', 'electropop', 'pop', 'post-teen ...  ...   0.523  -4.333
# 1554                     ['brega funk', 'funk carioca']  ...    0.55  -7.026
# 1555                           ['pop', 'post-teen pop']  ...   0.603  -7.176
#
#        habla Acústica vivacidad    Tempo Duracion (ms) Valencia Acorde ...
# 0     0.0504    0.127     0.359  134.002        211560    0.589      B NaN
# 1     0.0483   0.0383     0.103  169.928        141806    0.478  C#/Db NaN
# 2      0.154    0.335    0.0849  166.928        178147    0.688      A NaN
# 3     0.0348   0.0469     0.364  126.026        231041    0.591      B NaN
# 4     0.0615   0.0203    0.0501  149.995        212000    0.894  D#/Eb NaN
# ...      ...      ...       ...      ...           ...      ...    ...  ..
# 1551  0.0694  0.00261     0.153  116.073        209320    0.608      A NaN
# 1552  0.0851     0.24     0.333   152.37        181930    0.714      B NaN
# 1553    0.03    0.184     0.132  104.988        217307    0.394      D NaN
# 1554  0.0587    0.249     0.182  154.064        152784    0.881      F NaN
# 1555   0.064    0.433    0.0862  205.272        221307    0.422      G NaN
#
# [1556 rows x 24 columns]

# %% [markdown]
# # Eliminar los valores NaN:
#
# - Elige el método adecuado para eliminar los NaN según tu necesidad.
# - Eliminar filas con NaN: Utiliza el método dropna() para eliminar filas que contienen valores NaN.
# - Eliminar columnas con NaN: Utiliza el método dropna(axis=1) para eliminar columnas que contienen valores NaN.

# %%
df_limpiar.dropna(axis=1,how='all')
# Out:
#       Indice  Posición más alta en los gráficos  Número de veces registradas  \
# 0          1                                  1                            8
# 1          2                                  2                            3
# 2          3                                  1                           11
# 3          4                                  3                            5
# 4          5                                  5                            1
# ...      ...                                ...                          ...
# 1551    1552                                195                            1
# 1552    1553                                196                            1
# 1553    1554                                197                            1
# 1554    1555                                198                            1
# 1555    1556                                199                            1
#
#      Semana de gráficos más altos                Nombre de la cancion  \
# 0          2021-07-23--2021-07-30                             Beggin'
# 1          2021-07-23--2021-07-30           STAY (with Justin Bieber)
# 2          2021-06-25--2021-07-02                            good 4 u
# 3          2021-07-02--2021-07-09                          Bad Habits
# 4          2021-07-23--2021-07-30   INDUSTRY BABY (feat. Jack Harlow)
# ...                           ...                                 ...
# 1551       2019-12-27--2020-01-03                           New Rules
# 1552       2019-12-27--2020-01-03                  Cheirosa - Ao Vivo
# 1553       2019-12-27--2020-01-03           Havana (feat. Young Thug)
# 1554       2019-12-27--2020-01-03          Surtada - Remix Brega Funk
# 1555       2019-12-27--2020-01-03  Lover (Remix) [feat. Shawn Mendes]
#
#       Corrientes                        Artista Seguidores del Artista  \
# 0     48,633,449                       Måneskin                3377762
# 1     47,248,719                  The Kid LAROI                2230022
# 2     40,162,559                 Olivia Rodrigo                6266514
# 3     37,799,456                     Ed Sheeran               83293380
# 4     33,948,454                      Lil Nas X                5473565
# ...          ...                            ...                    ...
# 1551   4,630,675                       Dua Lipa               27167675
# 1552   4,623,030                 Jorge & Mateus               15019109
# 1553   4,620,876                 Camila Cabello               22698747
# 1554   4,607,385  Dadá Boladão, Tati Zaqui, OIK                 208630
# 1555   4,595,450                   Taylor Swift               42227614
#
#                   ID Cancion  \
# 0     3Wrjm47oTz2sjIgck11l5e
# 1     5HCyWlXZPP0y6Gqq8TgA20
# 2     4ZtFanR9U6ndgddUvNcjcG
# 3     6PQ88X9TkUIAUIZJHW2upE
# 4     27NovPIUIRrOZoCHxABJwK
# ...                      ...
# 1551  2ekn2ttSfGqwhhate0LSR0
# 1552  2PWjKmjyTZeDpmOUa3a5da
# 1553  1rfofaqEpACxVEHIZBJe6W
# 1554  5F8ffc8KWKNawllr5WsW0r
# 1555  3i9UVldZOE0aD0JnyfAZZ0
#
#                                                  Genero  ... Bailabilidad  \
# 0                ['indie rock italiano', 'italian pop']  ...        0.714
# 1                                ['australian hip hop']  ...        0.591
# 2                                               ['pop']  ...        0.563
# 3                                     ['pop', 'uk pop']  ...        0.808
# 4                         ['lgbtq+ hip hop', 'pop rap']  ...        0.736
# ...                                                 ...  ...          ...
# 1551                     ['dance pop', 'pop', 'uk pop']  ...        0.762
# 1552           ['sertanejo', 'sertanejo universitario']  ...        0.528
# 1553  ['dance pop', 'electropop', 'pop', 'post-teen ...  ...        0.765
# 1554                     ['brega funk', 'funk carioca']  ...        0.832
# 1555                           ['pop', 'post-teen pop']  ...        0.448
#
#      Energia Volumen   habla Acústica vivacidad    Tempo Duracion (ms)  \
# 0        0.8  -4.808  0.0504    0.127     0.359  134.002        211560
# 1      0.764  -5.484  0.0483   0.0383     0.103  169.928        141806
# 2      0.664  -5.044   0.154    0.335    0.0849  166.928        178147
# 3      0.897  -3.712  0.0348   0.0469     0.364  126.026        231041
# 4      0.704  -7.409  0.0615   0.0203    0.0501  149.995        212000
# ...      ...     ...     ...      ...       ...      ...           ...
# 1551     0.7  -6.021  0.0694  0.00261     0.153  116.073        209320
# 1552    0.87  -3.123  0.0851     0.24     0.333   152.37        181930
# 1553   0.523  -4.333    0.03    0.184     0.132  104.988        217307
# 1554    0.55  -7.026  0.0587    0.249     0.182  154.064        152784
# 1555   0.603  -7.176   0.064    0.433    0.0862  205.272        221307
#
#      Valencia Acorde
# 0       0.589      B
# 1       0.478  C#/Db
# 2       0.688      A
# 3       0.591      B
# 4       0.894  D#/Eb
# ...       ...    ...
# 1551    0.608      A
# 1552    0.714      B
# 1553    0.394      D
# 1554    0.881      F
# 1555    0.422      G
#
# [1556 rows x 23 columns]

# %% [markdown]
# ## Checamos que el Dataset no tenga NaNs

# %%
df_limpiar.isna().sum()
# Out:
# Indice                                  0
# Posición más alta en los gráficos       0
# Número de veces registradas             0
# Semana de gráficos más altos            0
# Nombre de la cancion                    0
# Corrientes                              0
# Artista                                 0
# Seguidores del Artista                  0
# ID Cancion                              0
# Genero                                  0
# Release Date                            0
# Weeks Charted                           0
# Popularity                              0
# Bailabilidad                            0
# Energia                                 0
# Volumen                                 0
# habla                                   0
# Acústica                                0
# vivacidad                               0
# Tempo                                   0
# Duracion (ms)                           0
# Valencia                                0
# Acorde                                  0
# ...                                  1556
# dtype: int64

# %% [markdown]
# # Estadísticos de Orden
#
# 1. Objetivos:
# - Aprender a calcular el rango y los percentiles usando pandas
#
# ---
#
# 2. Desarrollo:
#
# **Rango**
#
# El rango es simplemente la diferencia entre el valor máximo de un conjunto y el valor mínimo de un conjunto. Por lo tanto, podemos obtenerla de esta manera:

# %%
df.head()
# Out:
#    Index  Highest Charting Position  Number of Times Charted  \
# 0      1                          1                        8
# 1      2                          2                        3
# 2      3                          1                       11
# 3      4                          3                        5
# 4      5                          5                        1
#
#   Week of Highest Charting                          Song Name     Streams  \
# 0   2021-07-23--2021-07-30                            Beggin'  48,633,449
# 1   2021-07-23--2021-07-30          STAY (with Justin Bieber)  47,248,719
# 2   2021-06-25--2021-07-02                           good 4 u  40,162,559
# 3   2021-07-02--2021-07-09                         Bad Habits  37,799,456
# 4   2021-07-23--2021-07-30  INDUSTRY BABY (feat. Jack Harlow)  33,948,454
#
#            Artist Artist Followers                 Song ID  \
# 0        Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# 1   The Kid LAROI          2230022  5HCyWlXZPP0y6Gqq8TgA20
# 2  Olivia Rodrigo          6266514  4ZtFanR9U6ndgddUvNcjcG
# 3      Ed Sheeran         83293380  6PQ88X9TkUIAUIZJHW2upE
# 4       Lil Nas X          5473565  27NovPIUIRrOZoCHxABJwK
#
#                                     Genre  ... Danceability Energy Loudness  \
# 0  ['indie rock italiano', 'italian pop']  ...        0.714    0.8   -4.808
# 1                  ['australian hip hop']  ...        0.591  0.764   -5.484
# 2                                 ['pop']  ...        0.563  0.664   -5.044
# 3                       ['pop', 'uk pop']  ...        0.808  0.897   -3.712
# 4           ['lgbtq+ hip hop', 'pop rap']  ...        0.736  0.704   -7.409
#
#   Speechiness Acousticness Liveness    Tempo Duration (ms) Valence  Chord
# 0      0.0504        0.127    0.359  134.002        211560   0.589      B
# 1      0.0483       0.0383    0.103  169.928        141806   0.478  C#/Db
# 2       0.154        0.335   0.0849  166.928        178147   0.688      A
# 3      0.0348       0.0469    0.364  126.026        231041   0.591      B
# 4      0.0615       0.0203   0.0501  149.995        212000   0.894  D#/Eb
#
# [5 rows x 23 columns]

# %%
df['Highest Charting Position'].max()
# Out:
# 200

# %%
df ['Highest Charting Position'].min()
# Out:
# 1

# %%
rango= df['Highest Charting Position'].max()-df['Highest Charting Position'].min()

# %%
rango
# Out:
# 199

# %%
diccionario_casting ={
    'Streams':float
    
}

# %% [markdown]
# **Percentiles**
#
# El percentil P es un valor que indica que por lo menos P% de los valores en el conjunto tienen este valor o un valor menor; mientras que (100-P)% de los valores tienen este valor o un valor mayor. Por ejemplo, para obtener el percentil 80 primero ordenamos nuestro conjunto de manera ascendente y después elegimos un valor de manera que el 80% de los valores en nuestro conjunto sean iguales o menores a ese valor.
#
# En pandas, los percentiles están implementados como cuantiles, que es lo mismo que los percentiles pero en versión fracciones. Es decir, el percentil 80 es lo mismo que el cuantil 0.8.

# %%
df['Highest Charting Position'].median()
# Out:
# 80.0

# %%
df['Highest Charting Position'].quantile(0.5)
# Out:
# 80.0

# %%
df['Highest Charting Position'].quantile(0.8)
# Out:
# 148.0

# %%
df['Highest Charting Position'].quantile(0.25)
# Out:
# 37.0

# %%
df['Highest Charting Position'].quantile(0.75)
# Out:
# 137.0

# %% [markdown]
# ## Realizando los estadisticos con numpy

# %%
np.percentile(df['Highest Charting Position'],80)
# Out:
# 148.0

# %%
np.percentile(df['Highest Charting Position'],25)
# Out:
# 37.0

# %%
np.median(df['Highest Charting Position'])
# Out:
# 80.0

# %% [markdown]
# Anuncio: "En este caso, el 80% de los valores en…"
# Ing. Jose Luis Herrera Gallardo, MTI
# Fecha de creación: 16:4916:49
# En este caso, el 80% de los valores en nuestro conjunto de datos tienen un valor menor o igual a 1 440 000.
#
# Como podrás ya haber imaginado, el valor mínimo equivale al percentil 0 y el valor máximo equivale al percentil 100, mientras que la mediana es exactamente igual que el percentil 50.
#
# Sacando los percentiles podemos darnos una idea más o menos precisa de cómo están distribuidos nuestros datos.
#
# Por ejemplo:

# %%
def imprimirquantiles(datos):
    valor_minimo = datos.min()
    percentil_10 = datos.quantile(0.1)
    percentil_25= datos.quantile(2.25)
    percentil_50 = datos.median()
    percentil_75 =datos.quantile(0.75)
    percentil_90=datos.quantile(0.95)
    valor_maximo = datos.max()
    return{
'valor Minimo':valor_minimo,
'percentil 10':percentil_10,
'percentil 25':percentil_25,
'percentil 50':percentil_50,
'percentil 75':percentil_75,
'percentil 90':percentil_90,
'valor maximo' : valor_maximo,
}

# %% [markdown]
# Viendo estos números podemos inferir varias cosas:
#
# 1. Casi todos nuestros datos están concentrados en valores menores a 2 000 000.
# 1. Eso quiere decir que tenemos algunos valores atípicos demasiado grandes (si los comparamos con el resto de los valores)
# 1. La mediana nos estaba dando un número más cercano al verdadero "valor típico" que el promedio.
# 1. El promedio tenía un sesgo hacia arriba debido a los valores extremadamente grandes.
# 1. El rango entre el valor máximo y mínimo no nos da una medida representativa de qué valores pueden tomar nuestros datos.

# %% [markdown]
# **Rango intercuartílico**
#
# Otra medida muy común es lo que llamamos el rango intercuartílico, que es la diferencia entre el percentil 75 y el percentil 25. Este número nos da una idea del rango que tienen los valores más cercanos al valor típico.
#
# En nuestro ejemplo, nuestro rango intercuartílico sería:

# %%
#rango intercuatlico
df['Highest Charting Position'].quantile(0.75)-df['Highest Charting Position'].quantile(0.25)
# Out:
# 100.0

# %%
#Rango
df['Highest Charting Position'].max()- df['Highest Charting Position'].min()
# Out:
# 199

# %% [markdown]
# **La media o promedio**
#
# La media o promedio se obtiene sumando todos los valores de un conjunto de datos numéricos y dividiéndolos entre la cantidad de valores que tenemos en nuestro conjunto.
#
# Vamos a analizar la columna price. Veamos cuál es el "valor típico" obtenido usando la media (promedio):

# %%
df['Highest Charting Position'].mean()
# Out:
# 87.74421593830334

# %%
df.head(20)
# Out:
#     Index  Highest Charting Position  Number of Times Charted  \
# 0       1                          1                        8
# 1       2                          2                        3
# 2       3                          1                       11
# 3       4                          3                        5
# 5   67BtfxlNbhBmCDR2L2l8qd                      ['lgbtq+ hip hop', 'pop rap']
# 6   748mdHapucXQri7IAO8yFK                               ['dance pop', 'pop']
# 7   4fSIb4hdOQ151TILNsSEaF                ['puerto rican pop', 'trap latino']
# 8   2JPLbjOn0wPCngEot2STUS              ['latin', 'reggaeton', 'trap latino']
# 9   4pt5fDVTg5GhEvEtlz9dKk             ['indie rock italiano', 'italian pop']
# 10  463CkQjx2Zk1yXoBuierM9                     ['dance pop', 'pop', 'uk pop']
# 11  6hf0RpxTbOprT5nnwzkk8e     ['latin', 'reggaeton', 'reggaeton colombiano']
# 12  0LThjFY2iTtNdd4wviwVV2                       ['k-pop', 'k-pop boy group']
# 13  4iJyoBOLtHqaGxP12qzhQI           ['canadian pop', 'pop', 'post-teen pop']
# 14  2bgTY4UwhfBYhGT4HUYStN                       ['k-pop', 'k-pop boy group']
# 15  5CZ40GBx1sQ9agT82CLQCT                                            ['pop']
# 16  6HU7h9RYOaPRFeh0R3UeAr                                            ['pop']
# 17  37BZB0z9T8Xu7U3e65qxFy  ['canadian contemporary r&b', 'canadian pop', ...
# 18  05bfbizlM5AX6Mf1RRyMho              ['latin', 'reggaeton', 'trap latino']
# 19  3Vi5XqYrmQgOYBajMWSvCi                               ['dance pop', 'pop']
#
#     ... Danceability Energy Loudness Speechiness Acousticness Liveness  \
# 0   ...        0.714    0.8   -4.808      0.0504        0.127    0.359
# 1   ...        0.591  0.764   -5.484      0.0483       0.0383    0.103
# 2   ...        0.563  0.664   -5.044       0.154        0.335   0.0849
# 3   ...        0.808  0.897   -3.712      0.0348       0.0469    0.364
# 4   ...        0.736  0.704   -7.409      0.0615       0.0203   0.0501
# 5   ...         0.61  0.508   -6.682       0.152        0.297    0.384
# 6   ...        0.762  0.701   -3.541      0.0286        0.235    0.123
# 7   ...         0.78  0.718   -3.605      0.0506         0.31   0.0932
# 8   ...        0.644  0.648   -4.601       0.118        0.276    0.135
# 9   ...         0.75  0.608   -4.008      0.0387      0.00165    0.178
# 10  ...        0.702  0.825   -3.787      0.0601      0.00883   0.0674
# 11  ...        0.891  0.819   -3.964       0.106       0.0261    0.173
# 12  ...        0.702  0.741    -5.33      0.0427      0.00544    0.337
# 13  ...        0.677  0.696   -6.181       0.119        0.321     0.42
# 14  ...        0.759  0.459   -5.187      0.0948      0.00323   0.0906
# 15  ...         0.38  0.339   -7.885      0.0338        0.691     0.12
# 16  ...        0.442  0.612   -7.222       0.112        0.584     0.37
# 17  ...         0.65  0.825   -4.645      0.0325       0.0215   0.0936
# 18  ...        0.743  0.655   -5.015       0.159        0.114   0.0764
# 19  ...        0.664  0.609   -6.509      0.0707        0.304   0.0926
#
#       Tempo Duration (ms) Valence  Chord
# 0   134.002        211560   0.589      B
# 1   169.928        141806   0.478  C#/Db
# 2   166.928        178147   0.688      A
# 3   126.026        231041   0.591      B
# 4   149.995        212000   0.894  D#/Eb
# 5   178.818        137876   0.758  G#/Ab
# 6   110.968        208867   0.742  G#/Ab
# 7   127.949        199604   0.342  D#/Eb
# 8   179.951        206710    0.44  C#/Db
# 9   132.507        173347   0.958  C#/Db
# 10  102.977        203064   0.915  F#/Gb
# 11  101.968        217773   0.768  G#/Ab
# 12  124.925        187585   0.646      A
# 13    90.03        198082   0.464      C
# 14  109.997        164442   0.695  G#/Ab
# 15  100.607        229227  0.0849  D#/Eb
# 16  180.917        215507   0.178      D
# 17  118.091        191014   0.593      C
# 18  172.031        261335   0.785  F#/Gb
# 19  130.041        210560   0.194  C#/Db
#
# [20 rows x 23 columns]

# %%
df.dtypes
# Out:
# Index                         int64
# Highest Charting Position     int64
# Number of Times Charted       int64
# Week of Highest Charting     object
# Song Name                    object
# Streams                      object
# Artist                       object
# Artist Followers             object
# Song ID                      object
# Genre                        object
# Release Date                 object
# Weeks Charted                object
# Popularity                   object
# Danceability                 object
# Energy                       object
# Loudness                     object
# Speechiness                  object
# Acousticness                 object
# Liveness                     object
# Tempo                        object
# Duration (ms)                object
# Valence                      object
# Chord                        object
# dtype: object

# %% [markdown]
# **La mediana**
#
# La mediana se obtiene de la siguiente manera:
#
# 1. Primero ordenamos de manera ascendente nuestros datos
# 2. Luego tomamos el valor que está justo en medio de nuestra secuencia ordenada de valores.
# 3. Si nuestro conjunto tiene un número par de valores y por lo tanto no tiene un valor justo a la mitad de la secuencia, se toma el promedio de los dos valores que se encuentran a la mitad de la secuencia.
#
# Ahora veamos el "valor típico" obtenido usando la mediana:

# %%
df['Highest Charting Position'].median()
# Out:
# 80.0

# %% [markdown]
# # Media Truncada
#
# 1. Objetivos:
#
# - Aprender a estimar la media truncada usando scipy.
#
# --
#
# 2. Desarrollo:
#
# La media truncada es un estimado de locación más robusto que el promedio y la mediana.
# Esto significa que es menos sensible a valores atípicos. La media truncada se obtiene de la siguiente manera:
#
# 1. Primero ordenamos nuestro conjunto de manera ascendente.
# 2. Después decidimos qué porcentaje de nuestros datos vamos a truncar. Los valores más comunes suelen variar entre 5% y 25%.
# 3. Divide el porcentaje acordado entre dos y elimina esa fracción de tus
# datos del inicio y del final de tu secuencia. Por ejemplo, si decides truncar un 5%,
# elimina el 2.5% de tus datos del inicio de tu secuencia y el otro 2.5% del final de tu secuencia.
# 4. Obtén el promedio de los valores restantes.
#
# Afortunadamente, no tenemos que hacer esto manualmente.
# La librería scipy ya ofrece un método para obtener la media truncada fácilmente:

# %%
from scipy.stats import trim_mean

# %%
df['Highest Charting Position'].median()
# Out:
# 80.0

# %%
df['Highest Charting Position'].mean()
# Out:
# 87.74421593830334

# %%
porcion_truncar =0.1
trim_mean(df['Highest Charting Position'],porcion_truncar)
# Out:
# 85.51284109149277

# %%
porcion_truncar =0.1
media_truncada_precio =trim_mean(df['Highest Charting Position'],porcion_truncar)

# %%
media_truncada_precio
# Out:
# 85.51284109149277

# %%
import seaborn as sns

# %%
import pandas as pd

# %% [markdown]
# Seaborn es una herramienta de visualización altamente eficiente disponible en Python para crear gráficos impresionantes. Utiliza y se basa en el módulo matplotlib.

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

sns.pairplot(df)

# %%
print(df.head())
# Out:
#    Index  Highest Charting Position  Number of Times Charted  \
# 0      1                          1                        8
# 1      2                          2                        3
# 2      3                          1                       11
# 3      4                          3                        5
# 4      5                          5                        1
#
#   Week of Highest Charting                          Song Name     Streams  \
# 0   2021-07-23--2021-07-30                            Beggin'  48,633,449
# 1   2021-07-23--2021-07-30          STAY (with Justin Bieber)  47,248,719
# 2   2021-06-25--2021-07-02                           good 4 u  40,162,559
# 3   2021-07-02--2021-07-09                         Bad Habits  37,799,456
# 4   2021-07-23--2021-07-30  INDUSTRY BABY (feat. Jack Harlow)  33,948,454
#
#            Artist Artist Followers                 Song ID  \
# 0        Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# 1   The Kid LAROI          2230022  5HCyWlXZPP0y6Gqq8TgA20
# 2  Olivia Rodrigo          6266514  4ZtFanR9U6ndgddUvNcjcG
# 3      Ed Sheeran         83293380  6PQ88X9TkUIAUIZJHW2upE
# 4       Lil Nas X          5473565  27NovPIUIRrOZoCHxABJwK
#
#                                     Genre  ... Danceability Energy Loudness  \
# 0  ['indie rock italiano', 'italian pop']  ...        0.714    0.8   -4.808
# 1                  ['australian hip hop']  ...        0.591  0.764   -5.484
# 2                                 ['pop']  ...        0.563  0.664   -5.044
# 3                       ['pop', 'uk pop']  ...        0.808  0.897   -3.712
# 4           ['lgbtq+ hip hop', 'pop rap']  ...        0.736  0.704   -7.409
#
#   Speechiness Acousticness Liveness    Tempo Duration (ms) Valence  Chord
# 0      0.0504        0.127    0.359  134.002        211560   0.589      B
# 1      0.0483       0.0383    0.103  169.928        141806   0.478  C#/Db
# 2       0.154        0.335   0.0849  166.928        178147   0.688      A
# 3      0.0348       0.0469    0.364  126.026        231041   0.591      B
# 4      0.0615       0.0203   0.0501  149.995        212000   0.894  D#/Eb
#
# [5 rows x 23 columns]

# %% [markdown]
# # Selección de variables
#
# Ten en cuenta que también puedes seleccionar las variables que quieras incluir en la representación con vars. En caso de que quieras incluir distintas variables para los ejes X e Y puedes utilizar los argumentos x_vars e y_bars en su lugar.

# %%
print(df.columns)
# Out:
# Index(['Index', 'Highest Charting Position', 'Number of Times Charted',
#        'Week of Highest Charting', 'Song Name', 'Streams', 'Artist',
#        'Artist Followers', 'Song ID', 'Genre', 'Release Date', 'Weeks Charted',
#        'Popularity', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
#        'Acousticness', 'Liveness', 'Tempo', 'Duration (ms)', 'Valence',
#        'Chord'],
#       dtype='object')

# %%
import seaborn as sns

sns.pairplot(df, vars = ["Number of Times Charted", "Valence"])

# %%
import ast

# Función para extraer el primer género de manera segura
def extract_first_genre(genre_str):
    try:
        genres = ast.literal_eval(genre_str)
        if isinstance(genres, list) and genres:
            return genres[0]
        else:
            return 'Unknown'
    except (ValueError, SyntaxError):
        return 'Unknown'

# Aplicar la función a la columna 'Genre'
df['Primary Genre'] = df['Genre'].apply(extract_first_genre)

# Convertir la columna 'Energy' a numérica
df['Energy'] = pd.to_numeric(df['Energy'], errors='coerce')

# Crear la gráfica de violín
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
sns.violinplot(x='Primary Genre', y='Energy', data=df)

# Ajustar las etiquetas para que no se superpongan
plt.xticks(rotation=90)

# Mostrar la gráfica
plt.title('Distribución de Energía por Género')
plt.xlabel('Género')
plt.ylabel('Energía')
plt.show()

# %%
sns.scatterplot (data= df, x = 'Danceability', y = 'Energy')
# Out:
# <Axes: xlabel='Danceability', ylabel='Energy'>
